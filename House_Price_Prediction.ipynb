# %% [markdown]
# ### Required libraries

# %%
import pandas as pd
import numpy as np
import math
from datetime import datetime as dt

from sklearn.model_selection import train_test_split, cross_val_score, GridSearchCV
from sklearn.linear_model import LinearRegression, LogisticRegression
from sklearn.tree import DecisionTreeClassifier, DecisionTreeRegressor 
from sklearn.preprocessing import PolynomialFeatures
from sklearn.ensemble import RandomForestRegressor
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import mean_squared_error, make_scorer, accuracy_score 
from sklearn import preprocessing
from scipy import stats
from dmba import backward_elimination, forward_selection, stepwise_selection
from dmba import adjusted_r2_score, AIC_score, BIC_score
from dmba import plotDecisionTree, classificationSummary, regressionSummary
import statsmodels.formula.api as sm
from haversine import haversine, Unit


import matplotlib.pyplot as plt
import seaborn as sns
from matplotlib import style
# %matplotlib inline

import warnings
warnings.filterwarnings('ignore')
# Out:
# no display found. Using non-interactive Agg backend

# %% [markdown]
# # 1. Load Data

# %%
home_sales = pd.read_csv('training_dataset.csv')

# %%
# Use the head method to display the first 5 rows
home_sales.head(3)
# Out:
#            id             date   price  bedrooms  bathrooms  sqft_living  \
# 0  3787000140  20140901T000000  450000         3       2.25         1780
# 1  1934800078  20140930T000000  430000         2       2.25         1040
# 2  7331900290  20140731T000000  230000         4       1.50         1520
#
#    sqft_lot  floors  waterfront  view  ...  grade  sqft_above  sqft_basement  \
# 0      9969     1.0           0     0  ...      8        1450            330
# 1      1516     2.0           0     0  ...      8        1040              0
# 2      8800     1.0           0     0  ...      7        1520              0
#
#    yr_built  yr_renovated  zipcode      lat     long  sqft_living15  \
# 0      1985             0    98034  47.7286 -122.168           1950
# 1      2008             0    98122  47.6037 -122.307           1560
# 2      1960             0    98002  47.3136 -122.208           1370
#
#    sqft_lot15
# 0        7974
# 1        1920
# 2        8800
#
# [3 rows x 21 columns]

# %%
# Check the shape of the DataFrame (rows, columns)
home_sales.shape
# Out:
# (17614, 21)

# %%
home_sales.info()
# We notice that there is no NaN values in the Data set
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17614 entries, 0 to 17613
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   id             17614 non-null  int64
#  1   date           17614 non-null  object
#  2   price          17614 non-null  int64
#  3   bedrooms       17614 non-null  int64
#  4   bathrooms      17614 non-null  float64
#  5   sqft_living    17614 non-null  int64
#  6   sqft_lot       17614 non-null  int64
#  7   floors         17614 non-null  float64
#  8   waterfront     17614 non-null  int64
#  9   view           17614 non-null  int64
#  10  condition      17614 non-null  int64
#  11  grade          17614 non-null  int64
#  12  sqft_above     17614 non-null  int64
#  13  sqft_basement  17614 non-null  int64
#  14  yr_built       17614 non-null  int64
#  15  yr_renovated   17614 non-null  int64
#  16  zipcode        17614 non-null  int64
#  17  lat            17614 non-null  float64
#  18  long           17614 non-null  float64
#  19  sqft_living15  17614 non-null  int64
#  20  sqft_lot15     17614 non-null  int64
# dtypes: float64(4), int64(16), object(1)
# memory usage: 2.8+ MB

# %%
# count for the unique values in each variable, which is also useful to understand their distribution
for column in home_sales.columns:
    uniques = home_sales[column].unique()
    print('{0:20s} {1:5d}\t'.format(column, len(uniques)), uniques[:5])
# Out:
# id                   17494	 [3787000140 1934800078 7331900290 3438500798 2697400020]
# date                   370	 ['20140901T000000' '20140930T000000' '20140731T000000' '20140715T000000'
#  '20141031T000000']
# price                 3595	 [450000 430000 230000 275000 400000]
# bedrooms                12	 [3 2 4 1 5]
# bathrooms               30	 [2.25 1.5  2.   1.   2.5 ]
# sqft_living            953	 [1780 1040 1520 1060 1350]
# sqft_lot              8515	 [9969 1516 8800 6954 7216]
# floors                   6	 [1.  2.  1.5 2.5 3. ]
# waterfront               2	 [0 1]
# view                     5	 [0 2 1 4 3]
# condition                5	 [3 4 5 2 1]
# grade                   12	 [ 8  7  6 10  5]
# sqft_above             870	 [1450 1040 1520 1060 1350]
# sqft_basement          286	 [330   0 460 650 120]
# yr_built               116	 [1985 2008 1960 1983 1964]
# yr_renovated            68	 [   0 1984 2008 2014 2002]
# zipcode                 70	 [98034 98122 98002 98106 98177]
# lat                   4853	 [47.7286 47.6037 47.3136 47.5498 47.7616]
# long                   729	 [-122.168 -122.307 -122.208 -122.355 -122.365]
# sqft_living15          732	 [1950 1560 1370 1920 1030]
# sqft_lot15            7685	 [7974 1920 8800 6954 7600]

# %%
# Use the describe method to generates descriptive statistics that summarize the central 
# tendency, dispersion and shape of the dataset’s distribution, excluding NaN values
home_sales.describe()
# Out:
#                  id         price      bedrooms     bathrooms   sqft_living  \
# count  1.761400e+04  1.761400e+04  17614.000000  17614.000000  17614.000000
# mean   4.569068e+09  5.408514e+05      3.372431      2.113475   2080.915692
# std    2.869570e+09  3.685506e+05      0.935641      0.773550    923.863759
# min    1.000102e+06  7.500000e+04      0.000000      0.000000    290.000000
# 25%    2.122052e+09  3.225000e+05      3.000000      1.500000   1420.000000
# 50%    3.904985e+09  4.500000e+05      3.000000      2.250000   1910.000000
# 75%    7.300200e+09  6.450000e+05      4.000000      2.500000   2550.000000
# max    9.900000e+09  7.700000e+06     33.000000      8.000000  13540.000000
#
#            sqft_lot        floors    waterfront          view     condition  \
# count  1.761400e+04  17614.000000  17614.000000  17614.000000  17614.000000
# mean   1.513310e+04      1.495856      0.007097      0.233848      3.409844
# std    4.194362e+04      0.540092      0.083944      0.765230      0.649949
# min    5.200000e+02      1.000000      0.000000      0.000000      1.000000
# 25%    5.053250e+03      1.000000      0.000000      0.000000      3.000000
# 50%    7.607000e+03      1.500000      0.000000      0.000000      3.000000
# 75%    1.065000e+04      2.000000      0.000000      0.000000      4.000000
# max    1.651359e+06      3.500000      1.000000      4.000000      5.000000
#
#               grade    sqft_above  sqft_basement      yr_built  yr_renovated  \
# count  17614.000000  17614.000000   17614.000000  17614.000000  17614.000000
# mean       7.660100   1789.456398     291.459294   1970.917566     80.774384
# std        1.179174    831.418845     443.419741     29.425821    393.288442
# min        1.000000    290.000000       0.000000   1900.000000      0.000000
# 25%        7.000000   1190.000000       0.000000   1951.000000      0.000000
# 50%        7.000000   1560.000000       0.000000   1975.000000      0.000000
# 75%        8.000000   2210.000000     560.000000   1997.000000      0.000000
# max       13.000000   9410.000000    4820.000000   2015.000000   2015.000000
#
#             zipcode           lat          long  sqft_living15     sqft_lot15
# count  17614.000000  17614.000000  17614.000000   17614.000000   17614.000000
# mean   98078.043204     47.560487   -122.214127    1985.633303   12680.009424
# std       53.473239      0.138408      0.140161     685.581487   26713.761385
# min    98001.000000     47.155900   -122.519000     399.000000     659.000000
# 25%    98033.000000     47.471600   -122.328000    1480.000000    5100.000000
# 50%    98065.000000     47.572700   -122.230000    1840.000000    7600.000000
# 75%    98118.000000     47.678000   -122.125000    2360.000000   10057.250000
# max    98199.000000     47.777600   -121.315000    6210.000000  871200.000000

# %% [markdown]
# # 2. Feature Engineering

# %% [markdown]
# ### 2.1 Feature distribution
#
# Plot the density distribution for all variables in order to decide the feature parsing method

# %%
features = ['price', 'bedrooms', 'bathrooms', 'floors', 'waterfront', 'view', 'condition', 'grade',
            'sqft_living','sqft_lot', 'sqft_above', 'sqft_basement', 'sqft_living15', 'sqft_lot15',
            'yr_built','yr_renovated', 'zipcode', 'lat', 'long', ]
features_frame = pd.melt(home_sales, value_vars = features)
dis_plot = sns.FacetGrid(features_frame, col = 'variable', col_wrap = 4, sharex = False, sharey = False, height=4)
dis_plot = dis_plot.map(sns.distplot, 'value', color='r')
dis_plot.set_xticklabels(rotation = 45)
plt.show()

# %% [markdown]
# ### 2.2 Features reationship with price

# %%
features_bar = ['bedrooms', 'bathrooms', 'floors', 'waterfront', 'view', 'condition', 
                'grade']
features_line = ['sqft_living','sqft_lot','sqft_above', 'sqft_basement', 'sqft_living15', 
                 'sqft_lot15']
for feature in features_bar:
    fig = plt.figure(figsize = (12, 4)) 
    home_sales.groupby(home_sales[feature]).mean()['price'].plot(kind='bar')
    plt.show()
for feature in features_line:
    fig = plt.figure(figsize = (12, 4)) 
    home_sales.groupby(home_sales[feature]).mean()['price'].plot(kind='line')
    plt.show()

# %% [markdown]
# ### 2.3    Price
#
# From the distribution plots above we notice that 'price' has a long tail rhs even after we have truncated some extreme values.
#
# We can use log scale tranfer, so that the distribution of price variable will close to a normal distribution.

# %%
#removing outliers from data:
print(home_sales['price'].mean(), home_sales['price'].std(), 
      home_sales['price'].mean() - 3 * home_sales['price'].std(), 
      home_sales['price'].mean() + 3 * home_sales['price'].std())
home_sales = home_sales[(home_sales['price'] > (home_sales['price'].mean() - 3 * home_sales['price'].std()))
                       & (home_sales['price'] < (home_sales['price'].mean() + 3 * home_sales['price'].std()))]
# Out:
# 540851.3554558874 368550.61193291494 -564800.4803428574 1646503.191254632

# %%
home_sales['price_log'] = np.log(home_sales['price'])

first_col = home_sales.pop('price_log')
home_sales.insert(0, 'price_log', first_col)    #move the log_price variable to the front

# %% [markdown]
# ### 2.4     Sale_date
#
# Transfer 'date' into datetime and drop the 'id' variable.
#
# Generate varible of sale_year, sale_month and sale_week to capture the seasonality of house price.

# %%
# Transfer 'date' into datetime and drop the 'id' variable.
home_sales['sale_date'] = [x[:8] for x in home_sales.date]
home_sales.sale_date = home_sales.sale_date.apply(lambda x: dt.strptime(x, '%Y%m%d'))
home_sales.drop(columns = 'date', inplace = True)
home_sales.drop(columns = 'id', inplace = True)

home_sales['sale_year'] = home_sales['sale_date'].dt.year
home_sales['sale_month'] = home_sales['sale_date'].dt.month
home_sales['sale_week'] = home_sales['sale_date'].dt.week

# %%
for feature in ['sale_year','sale_month', 'sale_week']:
    fig = plt.figure(figsize = (12, 4)) 
    home_sales.groupby(home_sales[feature]).mean()['price'].plot(kind='bar')
    plt.show()

# %% [markdown]
# ### 2.5    yr_built & yr_renovated
#
# We found that both 'yr_built' and 'yr_renovated' can represent the condition of the house
#
# Meanwhile, we think it's better to transfer year into age, and if the house has never been renovated, then it has a same age with its original age.

# %%
home_sales['age'] = pd.DatetimeIndex(home_sales['sale_date']).year - home_sales['yr_built']
home_sales['age_renew'] = np.where(home_sales.yr_renovated == 0,
                home_sales.age, 
                pd.DatetimeIndex(home_sales['sale_date']).year - home_sales.yr_renovated)

# %% [markdown]
# ### 2.6    Variables with 'sqft'
#
# From the distribution plots above we notice that most of the variables with 'sqft' have a long tail rhs, which leads to the variables's distribution are highly affected by its absolyte value.
# We use MinMax to reduce this effect:

# %%
scaler = preprocessing.MinMaxScaler()
sqft_names = ['sqft_living', 'sqft_lot', 'sqft_above', 'sqft_basement',
                            'sqft_living15', 'sqft_lot15']
home_sales[sqft_names] = scaler.fit_transform(home_sales[sqft_names])

# %% [markdown]
# ### 2.7    Lat & long
#
# 'lat' & 'long' represents the absolute location of the house. While a more direct variable related to house price should be the distance of the house to downtown.
# For King County, both Seattle and Bellevue are city center. Then we generate two extra varibales to denote these distance.

# %%
home_sales['lat_long'] = tuple(zip(home_sales.lat,home_sales.long))
home_sales['lat_long'].head()
# Out:
# 0    (47.7286, -122.168)
# 1    (47.6037, -122.307)
# 2    (47.3136, -122.208)
# 3    (47.5498, -122.355)
# 4    (47.7616, -122.365)
# Name: lat_long, dtype: object

# %%
seattle_latlong = [47.608013,-122.335167]
seattle_list = []
for i in home_sales['lat_long']:
    seattle_list.append(haversine((seattle_latlong),(i),unit = 'mi'))
print(seattle_list [:5])
print(len(seattle_list))
# Out:
# [11.398125908934658, 1.3455632835958153, 21.191636074427773, 4.12699245759895, 10.702195059127325]
# 17285

# %%
home_sales['distance_from_seattle'] = seattle_list

# %%
bellevue = tuple([47.610378, -122.200676])
bell_distances = []
for i in home_sales['lat_long']:
    bell_distances.append(haversine((bellevue),(i),unit = 'mi'))
bell_distances[:5]
print(len(bell_distances))
# Out:
# 17285

# %%
home_sales['distance_from_bellevue'] = bell_distances
home_sales.tail(3)
# Out:
#        price_log   price  bedrooms  bathrooms  sqft_living  sqft_lot  floors  \
# 17611  12.608199  299000         3       1.00     0.093185  0.004592     1.0
# 17612  12.880292  392500         3       1.75     0.173853  0.005091     1.0
# 17613  12.538967  279000         6       1.75     0.271210  0.006457     2.0
#
#        waterfront  view  condition  ...  sqft_lot15  sale_date  sale_year  \
# 17611           0     0          3  ...    0.008548 2014-08-13       2014
# 17612           0     0          4  ...    0.011186 2014-11-19       2014
# 17613           0     0          4  ...    0.008381 2015-04-16       2015
#
#        sale_month  sale_week  age  age_renew             lat_long  \
# 17611           8         33   59         59  (47.7763, -122.305)
# 17612          11         47   57         57  (47.7762, -122.337)
# 17613           4         16   60         60    (47.42, -122.323)
#
#        distance_from_seattle  distance_from_bellevue
# 17611              11.711862               12.448515
# 17612              11.620928               13.094383
# 17613              13.002864               14.339060
#
# [3 rows x 29 columns]

# %%
home_sales['distance_from_downtown']=home_sales[['distance_from_bellevue', 'distance_from_seattle']].min(axis=1)
home_sales.head(3)
# Out:
#    price_log   price  bedrooms  bathrooms  sqft_living  sqft_lot  floors  \
# 0  13.017003  450000         3       2.25     0.207232  0.005724     1.0
# 1  12.971540  430000         2       2.25     0.104312  0.000603     2.0
# 2  12.345835  230000         4       1.50     0.171071  0.005016     1.0
#
#    waterfront  view  condition  ...  sale_date  sale_year  sale_month  \
# 0           0     0          3  ... 2014-09-01       2014           9
# 1           0     0          3  ... 2014-09-30       2014           9
# 2           0     0          4  ... 2014-07-31       2014           7
#
#    sale_week  age  age_renew             lat_long  distance_from_seattle  \
# 0         36   29         29  (47.7286, -122.168)              11.398126
# 1         40    6          6  (47.6037, -122.307)               1.345563
# 2         31   54         54  (47.3136, -122.208)              21.191636
#
#    distance_from_bellevue  distance_from_downtown
# 0                8.308646                8.308646
# 1                4.974398                1.345563
# 2               20.508261               20.508261
#
# [3 rows x 30 columns]

# %% [markdown]
# ### 2.8 Drop redundant variables

# %%
home_sales.columns
# Out:
# Index(['price_log', 'price', 'bedrooms', 'bathrooms', 'sqft_living',
#        'sqft_lot', 'floors', 'waterfront', 'view', 'condition', 'grade',
#        'sqft_above', 'sqft_basement', 'yr_built', 'yr_renovated', 'zipcode',
#        'lat', 'long', 'sqft_living15', 'sqft_lot15', 'sale_date', 'sale_year',
#        'sale_month', 'sale_week', 'age', 'age_renew', 'lat_long',
#        'distance_from_seattle', 'distance_from_bellevue',
#        'distance_from_downtown'],
#       dtype='object')

# %%
home_sales.drop(columns=['price', 'sale_date',  'yr_built', 'yr_renovated', 'lat', 'long', 
                         'distance_from_bellevue','distance_from_seattle','lat_long'], inplace = True)
home_sales.columns
# Out:
# Index(['price_log', 'bedrooms', 'bathrooms', 'sqft_living', 'sqft_lot',
#        'floors', 'waterfront', 'view', 'condition', 'grade', 'sqft_above',
#        'sqft_basement', 'zipcode', 'sqft_living15', 'sqft_lot15', 'sale_year',
#        'sale_month', 'sale_week', 'age', 'age_renew',
#        'distance_from_downtown'],
#       dtype='object')

# %% [markdown]
# # 3. Data Visualization

# %% [markdown]
# ### 3.1 variables distribution after feature engineering

# %%
# Plot the histogram of all variables after feature engineering
features = ['price_log', 'bedrooms', 'bathrooms','floors', 'waterfront', 'view', 'condition', 'grade',
            'sqft_living', 'sqft_lot','sqft_above','sqft_basement','sqft_living15', 
            'sqft_lot15',
            'sale_year','sale_month', 'sale_week', 'age', 'age_renew',
            'zipcode', 'distance_from_downtown']

feature_frame = pd.melt(home_sales, value_vars = features)
dis_plot = sns.FacetGrid(feature_frame, col = 'variable', col_wrap = 3, sharex = False, sharey = False, height=4)
dis_plot = dis_plot.map(sns.histplot, 'value', color='r')
dis_plot.set_xticklabels(rotation = 45)
plt.show()

# %% [markdown]
# ### 3.2 Price distribution among features

# %%
style.use('fivethirtyeight')
cm = plt.cm.get_cmap('RdYlGn_r')
xy = range(1, 17286)
z = xy
for feature in home_sales[features[1:]]:
    scatter_plot = plt.scatter(home_sales[feature], home_sales['price_log'], label = feature, c = z, marker = 'o', s = 25, cmap = cm)
    plt.colorbar(scatter_plot)
    plt.xlabel('' + feature)
    plt.ylabel('price_log')
    plt.yticks([10.5, 11.0, 11.5, 12.0, 12.5, 13.0, 13.5, 14.0, 
                14.5, 15.0, 15.5],
               [10.5, 11.0, 11.5, 12.0, 12.5, 13.0, 13.5, 14.0, 
                14.5, 15.0, 15.5])
    plt.legend()
    plt.show()

# %% [markdown]
# ### 3.3 Correlation matrix
#
# Correlation matrix can be useful to get a general idea about the relationship between house price and the correaponding features, as well as the correlation between features themselves.

# %%
corr_features = ['price_log', 'bedrooms', 'bathrooms','floors', 'waterfront', 'view', 
                 'condition', 'grade','sqft_living', 'sqft_lot','sqft_above',
                 'sqft_basement','sqft_living15', 'sqft_lot15','sale_year',
                 'sale_month', 'sale_week', 'age', 'age_renew','distance_from_downtown']
corr_matrix = home_sales[corr_features].corr()
plt.figure(figsize = (18, 18))
sns.heatmap(corr_matrix, annot = True, cmap = 'coolwarm', linecolor = 'black', 
            linewidths = 1.0, xticklabels = True, yticklabels = True)
plt.show()

# %% [markdown]
# # 4. Feature Selection and Model Fitting

# %%
#create dummy variables for 70 zipcodes
home_sales = pd.get_dummies(home_sales, columns = ['zipcode', 'sale_year','sale_month', 
                                                   'sale_week'], drop_first = True)

full_features = home_sales.columns[1:]
train_X = home_sales[full_features]
train_y = home_sales['price_log']

# %%
full_features
# Out:
# Index(['bedrooms', 'bathrooms', 'sqft_living', 'sqft_lot', 'floors',
#        'waterfront', 'view', 'condition', 'grade', 'sqft_above',
#        ...
#        'sale_week_43', 'sale_week_44', 'sale_week_45', 'sale_week_46',
#        'sale_week_47', 'sale_week_48', 'sale_week_49', 'sale_week_50',
#        'sale_week_51', 'sale_week_52'],
#       dtype='object', length=148)

# %% [markdown]
# ### 4.1 Forward Selection

# %%
# The initial model is the constant model - this requires special handling
# in train_model and score_model
def train_model(variables):
    if len(variables) == 0:
        return None
    model = LinearRegression()
    model.fit(train_X[variables], train_y)
    return model

def score_model(model, variables):
    if len(variables) == 0:
        return AIC_score(train_y, [train_y.mean()] * len(train_y), model, df=1)
    return AIC_score(train_y, model.predict(train_X[variables]), model)
best_model_forward, best_variables_forward = forward_selection(train_X.columns, train_model, score_model, verbose=True)
print(best_variables_forward)
# Out:
# Variables: bedrooms, bathrooms, sqft_living, sqft_lot, floors, waterfront, view, condition, grade, sqft_above, sqft_basement, sqft_living15, sqft_lot15, age, age_renew, distance_from_downtown, zipcode_98002, zipcode_98003, zipcode_98004, zipcode_98005, zipcode_98006, zipcode_98007, zipcode_98008, zipcode_98010, zipcode_98011, zipcode_98014, zipcode_98019, zipcode_98022, zipcode_98023, zipcode_98024, zipcode_98027, zipcode_98028, zipcode_98029, zipcode_98030, zipcode_98031, zipcode_98032, zipcode_98033, zipcode_98034, zipcode_98038, zipcode_98039, zipcode_98040, zipcode_98042, zipcode_98045, zipcode_98052, zipcode_98053, zipcode_98055, zipcode_98056, zipcode_98058, zipcode_98059, zipcode_98065, zipcode_98070, zipcode_98072, zipcode_98074, zipcode_98075, zipcode_98077, zipcode_98092, zipcode_98102, zipcode_98103, zipcode_98105, zipcode_98106, zipcode_98107, zipcode_98108, zipcode_98109, zipcode_98112, zipcode_98115, zipcode_98116, zipcode_98117, zipcode_98118, zipcode_98119, zipcode_98122, zipcode_98125, zipcode_98126, zipcode_98133, zipcode_98136, zipcode_98144, zipcode_98146, zipcode_98148, zipcode_98155, zipcode_98166, zipcode_98168, zipcode_98177, zipcode_98178, zipcode_98188, zipcode_98198, zipcode_98199, sale_year_2015, sale_month_2, sale_month_3, sale_month_4, sale_month_5, sale_month_6, sale_month_7, sale_month_8, sale_month_9, sale_month_10, sale_month_11, sale_month_12, sale_week_2, sale_week_3, sale_week_4, sale_week_5, sale_week_6, sale_week_7, sale_week_8, sale_week_9, sale_week_10, sale_week_11, sale_week_12, sale_week_13, sale_week_14, sale_week_15, sale_week_16, sale_week_17, sale_week_18, sale_week_19, sale_week_20, sale_week_21, sale_week_22, sale_week_23, sale_week_24, sale_week_25, sale_week_26, sale_week_27, sale_week_28, sale_week_29, sale_week_30, sale_week_31, sale_week_32, sale_week_33, sale_week_34, sale_week_35, sale_week_36, sale_week_37, sale_week_38, sale_week_39, sale_week_40, sale_week_41, sale_week_42, sale_week_43, sale_week_44, sale_week_45, sale_week_46, sale_week_47, sale_week_48, sale_week_49, sale_week_50, sale_week_51, sale_week_52
# Start: score=24029.46, constant
# Step: score=13768.17, add grade
# Step: score=6857.85, add distance_from_downtown
# Step: score=2818.92, add sqft_living
# Step: score=2109.67, add view
# Step: score=1522.60, add zipcode_98168
# Step: score=1007.99, add zipcode_98178
# Step: score=501.45, add zipcode_98106
# Step: score=7.45, add zipcode_98022
# Step: score=-514.58, add zipcode_98045
# Step: score=-933.38, add sqft_living15
# Step: score=-1332.24, add condition
# Step: score=-1726.65, add zipcode_98056
# Step: score=-2103.56, add zipcode_98055
# Step: score=-2479.64, add zipcode_98058
# Step: score=-2868.34, add zipcode_98108
# Step: score=-3292.29, add zipcode_98118
# Step: score=-3718.41, add zipcode_98146
# Step: score=-4091.46, add sqft_lot
# Step: score=-4418.43, add zipcode_98059
# Step: score=-4708.96, add waterfront
# Step: score=-4972.66, add zipcode_98065
# Step: score=-5225.16, add zipcode_98188
# Step: score=-5458.62, add zipcode_98144
# Step: score=-5720.32, add zipcode_98126
# Step: score=-5955.91, add zipcode_98031
# Step: score=-6180.70, add sale_year_2015
# Step: score=-6384.55, add zipcode_98198
# Step: score=-6574.17, add zipcode_98006
# Step: score=-6741.95, add zipcode_98004
# Step: score=-6889.98, add zipcode_98117
# Step: score=-7045.85, add zipcode_98105
# Step: score=-7214.84, add zipcode_98115
# Step: score=-7381.29, add sqft_above
# Step: score=-7529.13, add zipcode_98112
# Step: score=-7671.21, add zipcode_98042
# Step: score=-7812.35, add zipcode_98032
# Step: score=-7935.83, add zipcode_98030
# Step: score=-8054.02, add zipcode_98166
# Step: score=-8166.95, add zipcode_98133
# Step: score=-8269.78, add zipcode_98119
# Step: score=-8374.65, add zipcode_98103
# Step: score=-8472.84, add zipcode_98010
# Step: score=-8568.98, add zipcode_98199
# Step: score=-8660.98, add zipcode_98039
# Step: score=-8752.75, add zipcode_98107
# Step: score=-8847.09, add zipcode_98040
# Step: score=-8934.15, add zipcode_98109
# Step: score=-9025.11, add zipcode_98023
# Step: score=-9113.74, add zipcode_98033
# Step: score=-9198.21, add zipcode_98029
# Step: score=-9278.96, add zipcode_98053
# Step: score=-9354.10, add zipcode_98148
# Step: score=-9427.21, add zipcode_98102
# Step: score=-9484.95, add sale_month_4
# Step: score=-9541.93, add bathrooms
# Step: score=-9642.80, add age
# Step: score=-9753.30, add age_renew
# Step: score=-9809.58, add floors
# Step: score=-9863.09, add zipcode_98177
# Step: score=-9909.45, add zipcode_98002
# Step: score=-9954.77, add zipcode_98003
# Step: score=-9981.92, add zipcode_98116
# Step: score=-10005.54, add zipcode_98052
# Step: score=-10026.03, add zipcode_98092
# Step: score=-10041.23, add zipcode_98024
# Step: score=-10056.10, add sale_week_2
# Step: score=-10071.83, add sale_week_5
# Step: score=-10088.00, add sale_month_2
# Step: score=-10102.08, add zipcode_98122
# Step: score=-10119.43, add zipcode_98136
# Step: score=-10131.49, add zipcode_98125
# Step: score=-10145.25, add zipcode_98075
# Step: score=-10160.46, add zipcode_98072
# Step: score=-10177.20, add zipcode_98027
# Step: score=-10192.92, add zipcode_98014
# Step: score=-10205.43, add sale_week_3
# Step: score=-10215.58, add sale_week_4
# Step: score=-10223.63, add sale_month_3
# Step: score=-10230.42, add zipcode_98077
# Step: score=-10237.09, add sale_week_21
# Step: score=-10243.32, add zipcode_98074
# Step: score=-10252.03, add zipcode_98005
# Step: score=-10263.73, add zipcode_98034
# Step: score=-10277.66, add zipcode_98008
# Step: score=-10287.41, add zipcode_98019
# Step: score=-10295.67, add zipcode_98011
# Step: score=-10303.07, add zipcode_98070
# Step: score=-10312.76, add zipcode_98155
# Step: score=-10328.01, add zipcode_98028
# Step: score=-10370.97, add zipcode_98007
# Step: score=-10448.09, add zipcode_98038
# Step: score=-10450.51, add sale_month_6
# Step: score=-10453.21, add sale_week_26
# Step: score=-10454.83, add sale_week_15
# Step: score=-10456.12, add sqft_lot15
# Step: score=-10456.91, add sale_week_14
# Step: score=-10457.70, add bedrooms
# Step: score=-10458.36, add sale_week_12
# Step: score=-10458.36, add None
# ['grade', 'distance_from_downtown', 'sqft_living', 'view', 'zipcode_98168', 'zipcode_98178', 'zipcode_98106', 'zipcode_98022', 'zipcode_98045', 'sqft_living15', 'condition', 'zipcode_98056', 'zipcode_98055', 'zipcode_98058', 'zipcode_98108', 'zipcode_98118', 'zipcode_98146', 'sqft_lot', 'zipcode_98059', 'waterfront', 'zipcode_98065', 'zipcode_98188', 'zipcode_98144', 'zipcode_98126', 'zipcode_98031', 'sale_year_2015', 'zipcode_98198', 'zipcode_98006', 'zipcode_98004', 'zipcode_98117', 'zipcode_98105', 'zipcode_98115', 'sqft_above', 'zipcode_98112', 'zipcode_98042', 'zipcode_98032', 'zipcode_98030', 'zipcode_98166', 'zipcode_98133', 'zipcode_98119', 'zipcode_98103', 'zipcode_98010', 'zipcode_98199', 'zipcode_98039', 'zipcode_98107', 'zipcode_98040', 'zipcode_98109', 'zipcode_98023', 'zipcode_98033', 'zipcode_98029', 'zipcode_98053', 'zipcode_98148', 'zipcode_98102', 'sale_month_4', 'bathrooms', 'age', 'age_renew', 'floors', 'zipcode_98177', 'zipcode_98002', 'zipcode_98003', 'zipcode_98116', 'zipcode_98052', 'zipcode_98092', 'zipcode_98024', 'sale_week_2', 'sale_week_5', 'sale_month_2', 'zipcode_98122', 'zipcode_98136', 'zipcode_98125', 'zipcode_98075', 'zipcode_98072', 'zipcode_98027', 'zipcode_98014', 'sale_week_3', 'sale_week_4', 'sale_month_3', 'zipcode_98077', 'sale_week_21', 'zipcode_98074', 'zipcode_98005', 'zipcode_98034', 'zipcode_98008', 'zipcode_98019', 'zipcode_98011', 'zipcode_98070', 'zipcode_98155', 'zipcode_98028', 'zipcode_98007', 'zipcode_98038', 'sale_month_6', 'sale_week_26', 'sale_week_15', 'sqft_lot15', 'sale_week_14', 'bedrooms', 'sale_week_12']

# %%
len(best_variables_forward)
# Out:
# 98

# %% [markdown]
# ### 4.2 Backward Selection

# %%
def train_model(variables):
    model = LinearRegression()
    model.fit(train_X[variables], train_y)
    return model

def score_model(model, variables):
    return AIC_score(train_y, model.predict(train_X[variables]), model)


allVariables = train_X.columns
best_model_backward, best_variables_backward = backward_elimination(allVariables, train_model, score_model, verbose=True)
print(len(best_variables_backward))
# Out:
# Variables: bedrooms, bathrooms, sqft_living, sqft_lot, floors, waterfront, view, condition, grade, sqft_above, sqft_basement, sqft_living15, sqft_lot15, age, age_renew, distance_from_downtown, zipcode_98002, zipcode_98003, zipcode_98004, zipcode_98005, zipcode_98006, zipcode_98007, zipcode_98008, zipcode_98010, zipcode_98011, zipcode_98014, zipcode_98019, zipcode_98022, zipcode_98023, zipcode_98024, zipcode_98027, zipcode_98028, zipcode_98029, zipcode_98030, zipcode_98031, zipcode_98032, zipcode_98033, zipcode_98034, zipcode_98038, zipcode_98039, zipcode_98040, zipcode_98042, zipcode_98045, zipcode_98052, zipcode_98053, zipcode_98055, zipcode_98056, zipcode_98058, zipcode_98059, zipcode_98065, zipcode_98070, zipcode_98072, zipcode_98074, zipcode_98075, zipcode_98077, zipcode_98092, zipcode_98102, zipcode_98103, zipcode_98105, zipcode_98106, zipcode_98107, zipcode_98108, zipcode_98109, zipcode_98112, zipcode_98115, zipcode_98116, zipcode_98117, zipcode_98118, zipcode_98119, zipcode_98122, zipcode_98125, zipcode_98126, zipcode_98133, zipcode_98136, zipcode_98144, zipcode_98146, zipcode_98148, zipcode_98155, zipcode_98166, zipcode_98168, zipcode_98177, zipcode_98178, zipcode_98188, zipcode_98198, zipcode_98199, sale_year_2015, sale_month_2, sale_month_3, sale_month_4, sale_month_5, sale_month_6, sale_month_7, sale_month_8, sale_month_9, sale_month_10, sale_month_11, sale_month_12, sale_week_2, sale_week_3, sale_week_4, sale_week_5, sale_week_6, sale_week_7, sale_week_8, sale_week_9, sale_week_10, sale_week_11, sale_week_12, sale_week_13, sale_week_14, sale_week_15, sale_week_16, sale_week_17, sale_week_18, sale_week_19, sale_week_20, sale_week_21, sale_week_22, sale_week_23, sale_week_24, sale_week_25, sale_week_26, sale_week_27, sale_week_28, sale_week_29, sale_week_30, sale_week_31, sale_week_32, sale_week_33, sale_week_34, sale_week_35, sale_week_36, sale_week_37, sale_week_38, sale_week_39, sale_week_40, sale_week_41, sale_week_42, sale_week_43, sale_week_44, sale_week_45, sale_week_46, sale_week_47, sale_week_48, sale_week_49, sale_week_50, sale_week_51, sale_week_52
# Start: score=-10388.53
# Step: score=-10390.75, remove sqft_above
# Step: score=-10392.75, remove sale_month_10
# Step: score=-10394.75, remove sale_month_9
# Step: score=-10396.75, remove zipcode_98108
# Step: score=-10398.67, remove sale_week_52
# Step: score=-10400.53, remove zipcode_98106
# Step: score=-10402.27, remove zipcode_98003
# Step: score=-10403.96, remove sale_month_11
# Step: score=-10405.63, remove sale_week_4
# Step: score=-10407.23, remove sale_week_3
# Step: score=-10408.74, remove sale_month_8
# Step: score=-10410.73, remove sale_month_7
# Step: score=-10412.61, remove sale_month_2
# Step: score=-10414.53, remove sale_month_6
# Step: score=-10416.28, remove sale_week_8
# Step: score=-10417.89, remove sale_week_7
# Step: score=-10419.31, remove sale_week_51
# Step: score=-10420.64, remove sale_week_50
# Step: score=-10421.61, remove sale_week_6
# Step: score=-10422.52, remove sale_month_5
# Step: score=-10423.65, remove sale_month_4
# Step: score=-10425.16, remove sale_month_3
# Step: score=-10425.94, remove zipcode_98146
# Step: score=-10425.94, remove None
# 125

# %% [markdown]
# ### 4.3 Stepwise Selection

# %%
def train_model(variables):
    if len(variables) == 0:
        return None
    model = LinearRegression()
    model.fit(train_X[variables], train_y)
    return model

def score_model(model, variables):
    if len(variables) == 0:
        return AIC_score(train_y, [train_y.mean()] * len(train_y), model, df=1)
    return AIC_score(train_y, model.predict(train_X[variables]), model)

best_model_stepwise, best_variables_stepwise = stepwise_selection(train_X.columns, train_model, score_model, verbose=True)
print(len(best_variables_stepwise))
# Out:
# Variables: bedrooms, bathrooms, sqft_living, sqft_lot, floors, waterfront, view, condition, grade, sqft_above, sqft_basement, sqft_living15, sqft_lot15, age, age_renew, distance_from_downtown, zipcode_98002, zipcode_98003, zipcode_98004, zipcode_98005, zipcode_98006, zipcode_98007, zipcode_98008, zipcode_98010, zipcode_98011, zipcode_98014, zipcode_98019, zipcode_98022, zipcode_98023, zipcode_98024, zipcode_98027, zipcode_98028, zipcode_98029, zipcode_98030, zipcode_98031, zipcode_98032, zipcode_98033, zipcode_98034, zipcode_98038, zipcode_98039, zipcode_98040, zipcode_98042, zipcode_98045, zipcode_98052, zipcode_98053, zipcode_98055, zipcode_98056, zipcode_98058, zipcode_98059, zipcode_98065, zipcode_98070, zipcode_98072, zipcode_98074, zipcode_98075, zipcode_98077, zipcode_98092, zipcode_98102, zipcode_98103, zipcode_98105, zipcode_98106, zipcode_98107, zipcode_98108, zipcode_98109, zipcode_98112, zipcode_98115, zipcode_98116, zipcode_98117, zipcode_98118, zipcode_98119, zipcode_98122, zipcode_98125, zipcode_98126, zipcode_98133, zipcode_98136, zipcode_98144, zipcode_98146, zipcode_98148, zipcode_98155, zipcode_98166, zipcode_98168, zipcode_98177, zipcode_98178, zipcode_98188, zipcode_98198, zipcode_98199, sale_year_2015, sale_month_2, sale_month_3, sale_month_4, sale_month_5, sale_month_6, sale_month_7, sale_month_8, sale_month_9, sale_month_10, sale_month_11, sale_month_12, sale_week_2, sale_week_3, sale_week_4, sale_week_5, sale_week_6, sale_week_7, sale_week_8, sale_week_9, sale_week_10, sale_week_11, sale_week_12, sale_week_13, sale_week_14, sale_week_15, sale_week_16, sale_week_17, sale_week_18, sale_week_19, sale_week_20, sale_week_21, sale_week_22, sale_week_23, sale_week_24, sale_week_25, sale_week_26, sale_week_27, sale_week_28, sale_week_29, sale_week_30, sale_week_31, sale_week_32, sale_week_33, sale_week_34, sale_week_35, sale_week_36, sale_week_37, sale_week_38, sale_week_39, sale_week_40, sale_week_41, sale_week_42, sale_week_43, sale_week_44, sale_week_45, sale_week_46, sale_week_47, sale_week_48, sale_week_49, sale_week_50, sale_week_51, sale_week_52
# Start: score=24029.46, constant
# Step: score=13768.17, add grade
# Step: score=6857.85, add distance_from_downtown
# Step: score=2818.92, add sqft_living
# Step: score=2109.67, add view
# Step: score=1522.60, add zipcode_98168
# Step: score=1007.99, add zipcode_98178
# Step: score=501.45, add zipcode_98106
# Step: score=7.45, add zipcode_98022
# Step: score=-514.58, add zipcode_98045
# Step: score=-933.38, add sqft_living15
# Step: score=-1332.24, add condition
# Step: score=-1726.65, add zipcode_98056
# Step: score=-2103.56, add zipcode_98055
# Step: score=-2479.64, add zipcode_98058
# Step: score=-2868.34, add zipcode_98108
# Step: score=-3292.29, add zipcode_98118
# Step: score=-3718.41, add zipcode_98146
# Step: score=-4091.46, add sqft_lot
# Step: score=-4418.43, add zipcode_98059
# Step: score=-4708.96, add waterfront
# Step: score=-4972.66, add zipcode_98065
# Step: score=-5225.16, add zipcode_98188
# Step: score=-5458.62, add zipcode_98144
# Step: score=-5720.32, add zipcode_98126
# Step: score=-5955.91, add zipcode_98031
# Step: score=-6180.70, add sale_year_2015
# Step: score=-6384.55, add zipcode_98198
# Step: score=-6574.17, add zipcode_98006
# Step: score=-6741.95, add zipcode_98004
# Step: score=-6889.98, add zipcode_98117
# Step: score=-7045.85, add zipcode_98105
# Step: score=-7214.84, add zipcode_98115
# Step: score=-7381.29, add sqft_above
# Step: score=-7529.13, add zipcode_98112
# Step: score=-7671.21, add zipcode_98042
# Step: score=-7812.35, add zipcode_98032
# Step: score=-7935.83, add zipcode_98030
# Step: score=-8054.02, add zipcode_98166
# Step: score=-8166.95, add zipcode_98133
# Step: score=-8269.78, add zipcode_98119
# Step: score=-8374.65, add zipcode_98103
# Step: score=-8472.84, add zipcode_98010
# Step: score=-8568.98, add zipcode_98199
# Step: score=-8660.98, add zipcode_98039
# Step: score=-8752.75, add zipcode_98107
# Step: score=-8847.09, add zipcode_98040
# Step: score=-8934.15, add zipcode_98109
# Step: score=-9025.11, add zipcode_98023
# Step: score=-9113.74, add zipcode_98033
# Step: score=-9198.21, add zipcode_98029
# Step: score=-9278.96, add zipcode_98053
# Step: score=-9354.10, add zipcode_98148
# Step: score=-9427.21, add zipcode_98102
# Step: score=-9484.95, add sale_month_4
# Step: score=-9541.93, add bathrooms
# Step: score=-9642.80, add age
# Step: score=-9753.30, add age_renew
# Step: score=-9809.58, add floors
# Step: score=-9863.09, add zipcode_98177
# Step: score=-9909.45, add zipcode_98002
# Step: score=-9954.77, add zipcode_98003
# Step: score=-9981.92, add zipcode_98116
# Step: score=-10005.54, add zipcode_98052
# Step: score=-10026.03, add zipcode_98092
# Step: score=-10041.23, add zipcode_98024
# Step: score=-10056.10, add sale_week_2
# Step: score=-10071.83, add sale_week_5
# Step: score=-10088.00, add sale_month_2
# Step: score=-10102.08, add zipcode_98122
# Step: score=-10119.43, add zipcode_98136
# Step: score=-10131.49, add zipcode_98125
# Step: score=-10145.25, add zipcode_98075
# Step: score=-10160.46, add zipcode_98072
# Step: score=-10177.20, add zipcode_98027
# Step: score=-10192.92, add zipcode_98014
# Step: score=-10205.43, add sale_week_3
# Step: score=-10215.58, add sale_week_4
# Step: score=-10223.63, add sale_month_3
# Step: score=-10230.42, add zipcode_98077
# Step: score=-10237.09, add sale_week_21
# Step: score=-10243.32, add zipcode_98074
# Step: score=-10252.03, add zipcode_98005
# Step: score=-10263.73, add zipcode_98034
# Step: score=-10277.66, add zipcode_98008
# Step: score=-10287.41, add zipcode_98019
# Step: score=-10295.67, add zipcode_98011
# Step: score=-10303.07, add zipcode_98070
# Step: score=-10312.76, add zipcode_98155
# Step: score=-10328.01, add zipcode_98028
# Step: score=-10370.97, add zipcode_98007
# Step: score=-10448.09, add zipcode_98038
# Step: score=-10450.51, add sale_month_6
# Step: score=-10453.21, add sale_week_26
# Step: score=-10455.21, remove zipcode_98108
# Step: score=-10457.18, remove sale_month_4
# Step: score=-10459.06, remove zipcode_98106
# Step: score=-10460.80, remove zipcode_98003
# Step: score=-10462.04, add sqft_lot15
# Step: score=-10463.31, add sale_week_15
# Step: score=-10464.21, remove zipcode_98146
# Step: score=-10464.98, add bedrooms
# Step: score=-10465.31, add sale_week_14
# Step: score=-10465.89, add sale_week_12
# Step: score=-10465.89, unchanged None
# 93

# %%
len(best_variables_stepwise)
# Out:
# 93

# %%
# compare the feature selection results of different methods
print('stepwise not forward', set(best_variables_stepwise) - set(best_variables_forward), '\n')
print('forward not stepwise', set(best_variables_forward) - set(best_variables_stepwise), '\n')
print('stepwise not backward', set(best_variables_stepwise) - set(best_variables_backward), '\n')
print('backward not stepwise', set(best_variables_backward) - set(best_variables_stepwise), '\n')
print('forward not backward', set(best_variables_forward) - set(best_variables_backward), '\n')
print('backward not forward', set(best_variables_backward) - set(best_variables_forward), '\n')
# Out:
# stepwise not forward set()
#
# forward not stepwise {'sale_month_4', 'zipcode_98003', 'zipcode_98106', 'zipcode_98146', 'zipcode_98108'}
#
# stepwise not backward {'sale_month_3', 'sqft_above', 'sale_week_4', 'sale_week_3', 'sale_month_2', 'sale_month_6'}
#
# backward not stepwise {'sale_week_25', 'sqft_basement', 'sale_week_11', 'sale_week_49', 'sale_week_24', 'sale_week_36', 'sale_week_45', 'sale_month_12', 'sale_week_40', 'sale_week_44', 'sale_week_29', 'sale_week_46', 'sale_week_9', 'sale_week_32', 'sale_week_37', 'sale_week_33', 'sale_week_13', 'sale_week_23', 'sale_week_17', 'sale_week_30', 'sale_week_22', 'sale_week_16', 'sale_week_20', 'sale_week_28', 'sale_week_10', 'sale_week_34', 'sale_week_42', 'sale_week_35', 'sale_week_19', 'sale_week_48', 'sale_week_27', 'sale_week_18', 'sale_week_47', 'sale_week_31', 'sale_week_39', 'sale_week_43', 'sale_week_41', 'sale_week_38'}
#
# forward not backward {'sale_month_3', 'sqft_above', 'sale_week_4', 'sale_month_4', 'zipcode_98003', 'sale_week_3', 'zipcode_98106', 'zipcode_98146', 'sale_month_2', 'zipcode_98108', 'sale_month_6'}
#
# backward not forward {'sale_week_25', 'sqft_basement', 'sale_week_11', 'sale_week_49', 'sale_week_24', 'sale_week_36', 'sale_week_45', 'sale_month_12', 'sale_week_40', 'sale_week_44', 'sale_week_29', 'sale_week_46', 'sale_week_9', 'sale_week_32', 'sale_week_37', 'sale_week_33', 'sale_week_13', 'sale_week_23', 'sale_week_17', 'sale_week_30', 'sale_week_22', 'sale_week_16', 'sale_week_20', 'sale_week_28', 'sale_week_10', 'sale_week_34', 'sale_week_42', 'sale_week_35', 'sale_week_19', 'sale_week_48', 'sale_week_27', 'sale_week_18', 'sale_week_47', 'sale_week_31', 'sale_week_39', 'sale_week_43', 'sale_week_41', 'sale_week_38'}

# %% [markdown]
# ##### From the comparison above we notice that the selection result between forward and stepwise are very similar. The difference between backword and the other two methods mainly concentrates on the week, month and zipcodes.
# #####  For those important features including grade, distance_from_downtown, sqft_living and view, all of the three methods provide a similar result.
# ##### Therefore, we decide to use the features selected by forward for the next model fitting part.

# %% [markdown]
# ### 4.4 K-fold Cross Validation
#
# We use RMSE in this project as a the Accuracy Metric

# %%
from sklearn.model_selection import KFold
kf = KFold(n_splits=5)
print(kf)
# Out:
# KFold(n_splits=5, random_state=None, shuffle=False)

# %%
home_sales.columns
# Out:
# Index(['price_log', 'bedrooms', 'bathrooms', 'sqft_living', 'sqft_lot',
#        'floors', 'waterfront', 'view', 'condition', 'grade',
#        ...
#        'sale_week_43', 'sale_week_44', 'sale_week_45', 'sale_week_46',
#        'sale_week_47', 'sale_week_48', 'sale_week_49', 'sale_week_50',
#        'sale_week_51', 'sale_week_52'],
#       dtype='object', length=149)

# %%
def Cross_train_test_score(model, feature):
  
  X = home_sales.iloc[:, 1:][feature].to_numpy()
  Y = home_sales.iloc[:,0].to_numpy()

  acc_score_train = []
  acc_score_test = []

  for train_index, test_index in kf.split(X):
    x_trn, x_tst = X[train_index], X[test_index]
    y_trn, y_tst = Y[train_index], Y[test_index]
    
    model.fit(x_trn,y_trn)
    
    pred_train = model.predict(x_trn)
    pred_test = model.predict(x_tst)

    acc_train = round(np.sqrt(mean_squared_error(pred_train, y_trn)), 5)
    acc_score_train.append(acc_train)

    acc_test = round(np.sqrt(mean_squared_error(pred_test, y_tst)), 5)
    acc_score_test.append(acc_test)

  avg_acc_score_train = round(sum(acc_score_train)/5, 5)
  avg_acc_score_test = round(sum(acc_score_test)/5, 5)
  
  print('Train RMSE of each fold:', acc_score_train)
  print('Avg train RMSE : {}'.format(avg_acc_score_train))
    

  print('Test RMSE of each fold:',acc_score_test)
  print('Avg test RMSE : {}'.format(avg_acc_score_test))

# %% [markdown]
# #### 4.4.1 Linear regression

# %%
lrg_model = LinearRegression()
feature = best_variables_forward

Cross_train_test_score(lrg_model, best_variables_forward)
# Out:
# Train RMSE of each fold: [0.17765, 0.17837, 0.1764, 0.17763, 0.17796]
# Avg train RMSE : 0.1776
# Test RMSE of each fold: [0.17912, 0.17618, 0.18404, 0.1794, 0.17777]
# Avg test RMSE : 0.1793

# %% [markdown]
# #### 4.4.2 Regression Tree

# %%
# use the fullClassTree

# use the fullClassTree
X = home_sales.iloc[:, 1:]
Y = home_sales.iloc[:,0]

fullClassTree = DecisionTreeRegressor(criterion='mse',random_state=1, max_depth = None)
fullClassTree.fit(X[best_variables_forward], Y)
plotDecisionTree(fullClassTree, feature_names= best_variables_forward, max_depth=4)

# %%
Cross_train_test_score(fullClassTree, feature)
# Out:
# Train RMSE of each fold: [0.00819, 0.00545, 0.0092, 0.0067, 0.00942]
# Avg train RMSE : 0.00779
# Test RMSE of each fold: [0.26145, 0.25536, 0.26147, 0.26528, 0.25237]
# Avg test RMSE : 0.25919

# %% [markdown]
# ##### The model performance of full tree shows a significant feature of overfitting, which means it fits the training dataset well, but with high variance in test set.

# %%
param_grid = {
    'max_depth': [39, 41, 43, 45, 47], 
    'min_impurity_decrease': [0, 0.0001, 0.0002, 0.0003, 0.0004, 0.0005], 
    'min_samples_split': [70, 75, 80, 85, 90]
}
gridSearch = GridSearchCV(DecisionTreeRegressor(), param_grid, cv=5, n_jobs=-1)
gridSearch.fit(X[best_variables_forward], Y)
print('the bset parameters: ', gridSearch.best_params_)
# Out:
# the bset parameters:  {'max_depth': 45, 'min_impurity_decrease': 0, 'min_samples_split': 70}

# %%
param_grid = {
    'max_depth': [39, 41, 43, 45, 47], 
    'min_impurity_decrease': [0, 0.0001, 0.0002, 0.0003, 0.0004, 0.0005], 
    'min_samples_split': [66, 68, 70, 72, 74]
}
gridSearch = GridSearchCV(DecisionTreeRegressor(), param_grid, cv=5, n_jobs=-1)
gridSearch.fit(X[best_variables_forward], Y)
print('Improved parameters: ', gridSearch.best_params_)
# Out:
# Improved parameters:  {'max_depth': 47, 'min_impurity_decrease': 0, 'min_samples_split': 66}

# %%
feature = best_variables_forward

regTree = gridSearch.best_estimator_

Cross_train_test_score(regTree, feature)
# Out:
# Train RMSE of each fold: [0.17145, 0.1698, 0.16916, 0.16994, 0.16991]
# Avg train RMSE : 0.17005
# Test RMSE of each fold: [0.22291, 0.2132, 0.22607, 0.22592, 0.21373]
# Avg test RMSE : 0.22037

# %% [markdown]
# #### 4.4.3 Random Forest

# %%
rf_reg = RandomForestRegressor()
predictor = best_variables_forward

rf_model = rf_reg.fit(X, Y)
y_pred_rf = rf_model.predict(X)

rf_params = {'n_estimators':[10,20],'max_depth':[8,10],'max_leaf_nodes':[70,90]}
rf_grid = GridSearchCV(rf_reg,rf_params,cv = 5)
rf_model_two = rf_grid.fit(X,Y)
y_pred_rf_two = rf_model_two.predict(X)

# %%
rf_model_two.best_params_
# Out:
# {'max_depth': 10, 'max_leaf_nodes': 90, 'n_estimators': 20}

# %%
rf_params = {'n_estimators':[20],'max_depth':[10],'max_leaf_nodes':[90]}
rf_grid = GridSearchCV(rf_reg,rf_params,cv = 5)
rf_model_three = rf_grid.fit(X,Y)

Cross_train_test_score(rf_grid, feature)
# Out:
# Train RMSE of each fold: [0.20095, 0.20082, 0.20071, 0.2037, 0.20307]
# Avg train RMSE : 0.20185
# Test RMSE of each fold: [0.21867, 0.21203, 0.22022, 0.21706, 0.20913]
# Avg test RMSE : 0.21542

# %% [markdown]
# ##### After comparing the accuracy matric, we found that the Linear regression is the most robust and accuracy one.
# ##### Therefore, we finally decide to use linear regression to make the prediction in test set.

# %% [markdown]
# # 5. Results, findings

# %% [markdown]
# ### 5.1 Data processing of test dataset

# %%
home_sales_test = pd.read_csv('test_dataset.csv')

# %%
home_sales_test.head()
# Out:
#            id             date  bedrooms  bathrooms  sqft_living  sqft_lot  \
# 0  6825100015  20140604T000000         2       1.75         1500      6800
# 1  1698900195  20140902T000000         3       2.00         1880      3000
# 2  2848700585  20150424T000000         1       1.00          810      5000
# 3  2597690050  20150409T000000         4       1.75         1770      7336
# 4  8944600200  20140623T000000         3       2.50         1900      3255
#
#    floors  waterfront  view  condition  grade  sqft_above  sqft_basement  \
# 0     1.0           0     0          4      7         910            590
# 1     1.0           0     0          4      8        1040            840
# 2     1.0           0     1          3      7         590            220
# 3     1.0           0     0          4      8        1770              0
# 4     2.0           0     0          3      8        1900              0
#
#    yr_built  yr_renovated  zipcode      lat     long  sqft_living15  \
# 0      1942             0    98117  47.7004 -122.371           1450
# 1      1931             0    98109  47.6418 -122.351           1790
# 2      1936             0    98106  47.5696 -122.360           1920
# 3      1986             0    98058  47.4265 -122.163           2030
# 4      1988          2000    98007  47.6075 -122.147           1880
#
#    sqft_lot15
# 0        6800
# 1        3000
# 2        5000
# 3        8183
# 4        3350

# %%
home_sales_test.shape
# Out:
# (3999, 20)

# %%
home_sales_test.describe()
# Out:
#                  id     bedrooms    bathrooms  sqft_living       sqft_lot  \
# count  3.999000e+03  3999.000000  3999.000000  3999.000000    3999.000000
# mean   4.629782e+09     3.363841     2.120405  2075.424856   14991.852213
# std    2.907023e+09     0.905159     0.755135   894.263460   39037.889544
# min    1.000102e+06     0.000000     0.000000   370.000000     676.000000
# 25%    2.141250e+09     3.000000     1.750000  1430.000000    5001.000000
# 50%    3.886903e+09     3.000000     2.250000  1930.000000    7651.000000
# 75%    7.483950e+09     4.000000     2.500000  2540.000000   10800.000000
# max    9.842300e+09    11.000000     6.500000  8020.000000  982998.000000
#
#             floors   waterfront         view    condition        grade  \
# count  3999.000000  3999.000000  3999.000000  3999.000000  3999.000000
# mean      1.487497     0.009502     0.236309     3.407602     7.642661
# std       0.539550     0.097028     0.771180     0.654306     1.158992
# min       1.000000     0.000000     0.000000     1.000000     4.000000
# 25%       1.000000     0.000000     0.000000     3.000000     7.000000
# 50%       1.000000     0.000000     0.000000     3.000000     7.000000
# 75%       2.000000     0.000000     0.000000     4.000000     8.000000
# max       3.500000     1.000000     4.000000     5.000000    13.000000
#
#         sqft_above  sqft_basement     yr_built  yr_renovated       zipcode  \
# count  3999.000000    3999.000000  3999.000000   3999.000000   3999.000000
# mean   1783.696674     291.728182  1971.390848    100.381595  98077.484371
# std     813.356912     438.890155    29.141966    436.416510     53.649141
# min     370.000000       0.000000  1900.000000      0.000000  98001.000000
# 25%    1200.000000       0.000000  1951.000000      0.000000  98033.000000
# 50%    1560.000000       0.000000  1975.000000      0.000000  98065.000000
# 75%    2210.000000     570.000000  1997.000000      0.000000  98117.000000
# max    8020.000000    3500.000000  2015.000000   2015.000000  98199.000000
#
#                lat         long  sqft_living15     sqft_lot15
# count  3999.000000  3999.000000     3999.00000    3999.000000
# mean     47.558141  -122.212879     1990.60115   13158.026007
# std       0.139250     0.143744      684.62396   29766.127030
# min      47.176400  -122.511000      720.00000     651.000000
# 25%      47.467800  -122.330000     1497.50000    5040.000000
# 50%      47.567300  -122.233000     1850.00000    7700.000000
# 75%      47.678050  -122.123500     2370.00000   10145.000000
# max      47.777500  -121.319000     6110.00000  858132.000000

# %%
# 1) change data type of date, create sale_year, sale_month and sale_week
home_sales_test['sale_date'] = [x[:8] for x in home_sales_test.date]
home_sales_test.sale_date = home_sales_test.sale_date.apply(lambda x: dt.strptime(x, '%Y%m%d'))
home_sales_test.drop(columns = 'date', inplace = True)
home_sales_test.drop(columns = 'id', inplace = True)
home_sales_test['sale_year'] = home_sales_test['sale_date'].dt.year
home_sales_test['sale_month'] = home_sales_test['sale_date'].dt.month
home_sales_test['sale_week'] = home_sales_test['sale_date'].dt.week

# 2) create house age variables
home_sales_test['age'] = pd.DatetimeIndex(home_sales_test['sale_date']).year - home_sales_test['yr_built']
home_sales_test['age_renew'] = np.where(home_sales_test.yr_renovated == 0,
                home_sales_test.age, 
                pd.DatetimeIndex(home_sales_test['sale_date']).year - home_sales_test.yr_renovated)

# 3) Normalize variables related to sqft
scaler = preprocessing.MinMaxScaler()
sqft_names = ['sqft_living', 'sqft_lot', 'sqft_above', 'sqft_basement',
                            'sqft_living15', 'sqft_lot15']
home_sales_test[sqft_names] = scaler.fit_transform(home_sales_test[sqft_names])

# 4) create variable of distance to downtown
home_sales_test['lat_long'] = tuple(zip(home_sales_test.lat,home_sales_test.long))

seattle_latlong = [47.608013,-122.335167]
seattle_list_test = []
for i in home_sales_test['lat_long']:
    seattle_list_test.append(haversine((seattle_latlong),(i),unit = 'mi'))

home_sales_test['distance_from_seattle'] = seattle_list_test

bellevue = tuple([47.610378, -122.200676])
bell_distances_test = []
for i in home_sales_test['lat_long']:
    bell_distances_test.append(haversine((bellevue),(i),unit = 'mi'))
bell_distances_test[:5]

home_sales_test['distance_from_bellevue'] = bell_distances_test

home_sales_test['distance_from_downtown'] = home_sales_test[['distance_from_bellevue', 'distance_from_seattle']].min(axis=1)

home_sales_test.drop(columns=['lat','long', 'lat_long', 'distance_from_bellevue','distance_from_seattle' ], inplace = True)

# 5) generate dummies for zipcode', 'sale_year','sale_month' and 'sale_week'

home_sales_test = pd.get_dummies(home_sales_test, columns = ['zipcode', 'sale_year','sale_month', 
                                                   'sale_week'], drop_first =  True)
# 6) drop redundant variables:
home_sales_test = home_sales_test.drop(['sale_date', 'yr_built','yr_renovated'], axis = 1)

# %%
# Check if features in test dataset after frocessing is consistent with the model fitting part:
home_sales_test.columns == full_features
# Out:
# array([ True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True])

# %%
#Final Model
home_sales_test['price_log'] = lrg_model.predict(home_sales_test[best_variables_forward])

#transforming back from log price
home_sales_test['predict_price'] = np.exp(home_sales_test['price_log'])

# %%
# from google.colab import drive
# drive.mount('drive')

# %%
# from google.colab import files
# home_sales_test.to_csv('final_test_with_price.csv') 
# files.download('final_test_with_price.csv')
